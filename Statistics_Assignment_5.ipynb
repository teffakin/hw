# %% [markdown]
# <a href="https://colab.research.google.com/github/teffakin/hw/blob/main/Statistics_Assignment_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as plot
from scipy import stats

# %% [markdown]
# The hourly wages in a particular industry are normally distributed with mean 13.20 Dollar and standard deviation 2.50 Dollar. A company in this industry employs 40 workers, paying them an average of $12.20 per hour. Can this company be accused of paying substandard wages? Use an α = .01 level test.

# %%
mu = 13.20
sigma = 2.50

n=40

#H0 = 12.20 
#H1 < 12.20 (is significantly lower than 13.20)

alpha = 0.01

# %%
ttest = (12.20-13.20)/(2.50/np.sqrt(40))
ttest
# Out:
# -2.5298221281347035

# %%
p_value = stats.norm.cdf(ttest)
p_value
# Out:
# 0.005706018193000826

# %%
if p_value < alpha :
    print("Reject the null")
else :
    print("Fail to reject the null")
# Out:
# Reject the null

# %% [markdown]
# Shear strength measurements derived from unconfined compression tests for two types of soils gave the results shown in the following document (measurements in tons per square foot). Do the soils appear to differ with respect to average shear strength, at the 1% significance level?

# %%
df = pd.read_csv('soil.csv')
df
# Out:
#     Soil1  Soil2
# 0   1.442  1.364
# 1   1.943  1.878
# 2   1.110  1.337
# 3   1.912  1.828
# 4   1.553  1.371
# 5   1.641  1.428
# 6   1.499  1.119
# 7   1.347  1.373
# 8   1.685  1.589
# 9   1.578  1.714
# 10  1.866  1.260
# 11  1.653  1.492
# 12  1.665  1.395
# 13  1.640  1.778
# 14  1.976  1.611
# 15  1.754  1.202
# 16  1.589  1.542
# 17  1.976  1.094
# 18  1.863  1.557
# 19  1.932  1.053
# 20  1.570  1.183
# 21  1.613  1.367
# 22  2.054  1.144
# 23  1.550  1.151
# 24  1.714  1.561
# 25  1.896  1.192
# 26  1.737  1.489
# 27  1.740  1.379
# 28  1.708  1.501
# 29  1.548  1.277
# 30    NaN  1.593
# 31    NaN  1.172
# 32    NaN  1.510
# 33    NaN  1.740
# 34    NaN  1.355

# %% [markdown]
# H0 : mu1 = mu2
#
# H1 : mu1 != mu2

# %%
df.Soil1.mean()
# Out:
# 1.6918

# %%
df.Soil2.mean()
# Out:
# 1.4171142857142855

# %%
result = stats.ttest_ind(df.Soil1 , df.Soil2 , equal_var = True)
result
# Out:
# Ttest_indResult(statistic=nan, pvalue=nan)

# %%
stats.ttest_ind(df.dropna()['Soil1'] , df.Soil2 , equal_var = True)
# Out:
# Ttest_indResult(statistic=5.1681473319343345, pvalue=2.593228732352821e-06)

# %% [markdown]
# reject the H0

# %% [markdown]
# The following dataset is based on data provided by the World Bank (https://datacatalog.worldbank.org/dataset/education-statistics). World Bank Edstats.  2015 PISA Test Dataset
#
# Get descriptive statistics (the central tendency, dispersion and shape of a dataset’s distribution) for each continent group (AS, EU, AF, NA, SA, OC).
# Determine whether there is any difference (on the average) for the math scores among European (EU) and Asian (AS) countries (assume normality and equal variances). Draw side-by-side box plots.

# %%
df1 = pd.read_csv("2015_PISA_Test.csv")
df1
# Out:
#    Country Code Continent_Code  ...   Reading   Science
# 0           ALB             EU  ...  405.2588  427.2250
# 1           ARE             AS  ...  433.5423  436.7311
# 2           ARG             SA  ...  425.3031  432.2262
# 3           AUS             OC  ...  502.9006  509.9939
# 4           AUT             EU  ...  484.8656  495.0375
# ..          ...            ...  ...       ...       ...
# 65          TUN             AF  ...  361.0555  386.4034
# 66          TUR             EU  ...  428.3351  425.4895
# 67          URY             SA  ...  436.5721  435.3630
# 68          USA            NaN  ...  496.9351  496.2424
# 69          VNM             AS  ...  486.7738  524.6445
#
# [70 rows x 6 columns]

# %%
df1.describe()
# Out:
#        internet_users_per_100        Math     Reading     Science
# count               70.000000   70.000000   70.000000   70.000000
# mean                71.973099  460.971557  460.997291  465.439093
# std                 16.390632   53.327205   49.502679   48.397254
# min                 21.976068  327.702000  346.549000  331.638800
# 25%                 60.899020  417.416075  426.948625  425.923375
# 50%                 72.999350  477.607150  480.199850  475.400050
# 75%                 85.026763  500.482925  499.687475  502.431250
# max                 98.200000  564.189700  535.100200  555.574700

# %%
df1.groupby("Continent_Code").describe().T
# Out:
# Continent_Code                        AF          AS  ...          OC          SA
# internet_users_per_100 count    2.000000   17.000000  ...    2.000000    7.000000
#                        mean    43.359918   68.455613  ...   86.391704   60.180494
#                        std      7.297226   21.086060  ...    2.589686    9.772455
#                        min     38.200000   21.976068  ...   84.560519   40.900000
#                        25%     40.779959   50.300000  ...   85.476112   57.116462
#                        50%     43.359918   74.000000  ...   86.391704   64.289000
#                        75%     45.939877   84.948353  ...   87.307296   66.321532
#                        max     48.519836   92.884826  ...   88.222889   69.198471
# Math                   count    2.000000   17.000000  ...    2.000000    7.000000
#                        mean   363.212100  466.216647  ...  494.559750  402.887700
# ...

# %%
df1.groupby("Continent_Code").describe()['Math']
# Out:
#                 count        mean        std  ...        50%         75%       max
# Continent_Code                                ...
# AF                2.0  363.212100   5.099513  ...  363.21210  365.015050  366.8180
# AS               17.0  466.216647  64.356490  ...  459.81600  531.296100  564.1897
# EU               37.0  477.981449  35.150403  ...  489.72870  503.722000  521.2506
# OC                2.0  494.559750   0.938401  ...  494.55975  494.891525  495.2233
# SA                7.0  402.887700  18.128894  ...  409.03330  417.617650  422.6714
#
# [5 rows x 8 columns]

# %%
EU = df1[df1['Continent_Code'] == "EU"]['Math']
EU
# Out:
# 0     413.1570
# 4     496.7423
# 5     506.9844
# 6     441.1899
# 9     521.2506
# 14    437.1443
# 15    492.3254
# 16    505.9713
# 17    511.0876
# 20    485.8432
# 21    519.5291
# 22    511.0769
# 23    492.9204
# 24    492.4785
# 26    453.6299
# 28    464.0401
# 29    476.8309
# 31    503.7220
# 32    488.0332
# 34    489.7287
# 40    478.3834
# 41    485.7706
# 42    482.3051
# 44    419.6635
# 46    371.3114
# 47    478.6448
# 48    417.9341
# 50    512.2528
# 51    501.7298
# 54    504.4693
# 55    491.6270
# 57    443.9543
# 58    494.0600
# 60    475.2301
# 61    509.9196
# 62    493.9181
# 66    420.4540
# Name: Math, dtype: float64

# %%
AS = df1[df1['Continent_Code'] == "AS"]['Math']
AS
# Out:
# 1     427.4827
# 11    531.2961
# 25    403.8332
# 27    547.9310
# 30    386.1096
# 33    469.6695
# 35    380.2590
# 36    532.4399
# 37    459.8160
# 38    524.1062
# 39    396.2497
# 43    543.8078
# 49    446.1098
# 56    402.4007
# 59    564.1897
# 63    415.4638
# 69    494.5183
# Name: Math, dtype: float64

# %%
sns.boxplot(y='Math', x='Continent_Code', data = df1[(df1['Continent_Code'] == "AS") | (df1['Continent_Code'] == "EU")][['Math','Continent_Code']]);

# %% [markdown]
# H0 : Avg Msth EU = Avg Math AS
#
# H1 : Avg Msth EU != Avg Math AS

# %%
test = stats.ttest_ind(EU, AS,equal_var=True)
test
# Out:
# Ttest_indResult(statistic=0.870055317967983, pvalue=0.38826888111307345)

# %%
alpha = 0.05

if test.pvalue < alpha:
    print("Reject the null")
else:
    print("Fail to reject the null")
# Out:
# Fail to reject the null

# %% [markdown]
# The sample dataset has placement test scores (out of 100 points) for four subject areas: English, Reading, Math, and Writing. Students in the sample completed all 4 placement tests when they enrolled in the university. Suppose we are particularly interested in the English and Math sections, and want to determine whether students tended to score higher on their English or Math test, on average. We could use a paired t test to test if there was a significant difference in the average of the two tests.

# %%
df2 = pd.read_csv("students_2014.csv")
df2
# Out:
#        ids        bday  enrolldate  ... CommuteTime  SleepTime StudyTime
# 0    43783   3/22/1995         NaN  ...         NaN        7.0       1.0
# 1    20278    1/1/1995         NaN  ...         NaN        5.0       2.0
# 2    20389  12/31/1994         NaN  ...         NaN        8.0       7.0
# 3    22820   12/1/1994         NaN  ...         NaN        2.0       6.0
# 4    24559  11/10/1994         NaN  ...         NaN        7.0       3.0
# ..     ...         ...         ...  ...         ...        ...       ...
# 430  34021   7/18/1987  1-Aug-2011  ...        18.0        1.0      10.0
# 431  40697   4/29/1987  1-Aug-2011  ...        26.0        6.0      15.0
# 432  34272         NaN  1-Aug-2011  ...        29.0        6.0      10.0
# 433  33628         NaN  1-Aug-2011  ...        14.0        4.0      10.0
# 434  39298         NaN  1-Aug-2011  ...        27.0        2.0      10.0
#
# [435 rows x 23 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 435 entries, 0 to 434
# Data columns (total 23 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ids           435 non-null    int64
#  1   bday          427 non-null    object
#  2   enrolldate    406 non-null    object
#  3   expgradate    406 non-null    object
#  4   Rank          406 non-null    float64
#  5   Major         276 non-null    object
#  6   Gender        426 non-null    float64
#  7   Athlete       435 non-null    int64
#  8   Height        408 non-null    float64
#  9   Weight        376 non-null    float64
#  10  Smoking       411 non-null    float64
#  11  Sprint        374 non-null    float64
#  12  MileMinDur    392 non-null    object
#  13  English       409 non-null    float64
#  14  Reading       425 non-null    float64
#  15  Math          422 non-null    float64
#  16  Writing       404 non-null    float64
#  17  State         408 non-null    object
# ...

# %%
df2.describe()
# Out:
#                 ids        Rank  ...   SleepTime   StudyTime
# count    435.000000  406.000000  ...  403.000000  393.000000
# mean   35279.022989    2.199507  ...    5.461538    7.208651
# std     8637.733605    1.098641  ...    2.421994    4.356233
# min    20183.000000    1.000000  ...    0.000000    0.000000
# 25%    28001.000000    1.000000  ...    4.000000    4.000000
# 50%    35350.000000    2.000000  ...    5.000000    6.000000
# 75%    42655.500000    3.000000  ...    7.000000   10.000000
# max    49947.000000    4.000000  ...   13.000000   23.000000
#
# [8 rows x 17 columns]

# %%
pairedtest = stats.ttest_rel(df2.Math, df2.English, nan_policy='omit')
pairedtest
# Out:
# Ttest_relResult(statistic=-36.31256898171986, pvalue=3.071098719220689e-128)

# %% [markdown]
# There is a significant average difference between English and Math scores
